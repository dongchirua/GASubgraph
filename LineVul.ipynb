# %%
# %load_ext autoreload
# %autoreload 2

# %%
import torch
from torch.utils.data import DataLoader, Dataset, SequentialSampler
from dataclasses import dataclass
from transformers import RobertaTokenizer, RobertaForSequenceClassification, RobertaConfig

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
n_gpu = torch.cuda.device_count()

# %%
from linevul.linevul_model import Model
from linevul.linevul_helpers import TextDataset
from linevul.linevul_extra import extract_line_attention, linevul_predict

# %%
from vulexp.data_models.reveal_data import Reveal

# %%
import os
import pandas as pd
from tqdm.autonotebook import tqdm

# %%
config = RobertaConfig.from_pretrained('microsoft/codebert-base')
config.num_labels = 1
config.num_attention_heads = 12

# %%
@dataclass
class Args:
    device = device
    n_gpu = n_gpu
    use_non_pretrained_model = False
    block_size = 512
    code_length=256
    do_local_explanation=True
    reasoning_method='attention'
    seed=27
    num_attention_heads=12
    do_sorting_by_line_scores=False
    do_sorting_by_pred_prob=False
    top_k_constant=10
    use_word_level_tokenizer=False
    eval_batch_size=512
    gtype = 'cpg'

args = Args()

# %%
tokenizer = RobertaTokenizer.from_pretrained('microsoft/codebert-base')
encoder = RobertaForSequenceClassification.from_pretrained('microsoft/codebert-base', 
                                                             config=config, 
                                                             ignore_mismatched_sizes=True).to(device)
model = Model(encoder, config, tokenizer, args)
# Out:
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at microsoft/codebert-base and are newly initialized: ['classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight', 'classifier.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
checkpoint = '/workspace/12heads_linevul_model.bin'
state_dict = torch.load(checkpoint)
model.load_state_dict(state_dict, strict=False)
model.to(args.device)
# Out:
# Model(
#   (roberta): RobertaModel(
#     (embeddings): RobertaEmbeddings(
#       (word_embeddings): Embedding(50265, 768, padding_idx=1)
#       (position_embeddings): Embedding(514, 768, padding_idx=1)
#       (token_type_embeddings): Embedding(1, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): RobertaEncoder(
#       (layer): ModuleList(
#         (0): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (classifier): RobertaClassificationHead(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#     (out_proj): Linear(in_features=768, out_features=2, bias=True)
#   )
#   (encoder): RobertaForSequenceClassification(
#     (roberta): RobertaModel(
#       (embeddings): RobertaEmbeddings(
#         (word_embeddings): Embedding(50265, 768, padding_idx=1)
#         (position_embeddings): Embedding(514, 768, padding_idx=1)
#         (token_type_embeddings): Embedding(1, 768)
#         (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (encoder): RobertaEncoder(
#         (layer): ModuleList(
#           (0): RobertaLayer(
#             (attention): RobertaAttention(
#               (self): RobertaSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): RobertaSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): RobertaIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): RobertaOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (1): RobertaLayer(
#             (attention): RobertaAttention(
#               (self): RobertaSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): RobertaSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): RobertaIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): RobertaOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (2): RobertaLayer(
#             (attention): RobertaAttention(
#               (self): RobertaSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): RobertaSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): RobertaIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): RobertaOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (3): RobertaLayer(
#             (attention): RobertaAttention(
#               (self): RobertaSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): RobertaSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): RobertaIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): RobertaOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (4): RobertaLayer(
#             (attention): RobertaAttention(
#               (self): RobertaSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): RobertaSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): RobertaIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): RobertaOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (5): RobertaLayer(
#             (attention): RobertaAttention(
#               (self): RobertaSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): RobertaSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): RobertaIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): RobertaOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (6): RobertaLayer(
#             (attention): RobertaAttention(
#               (self): RobertaSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): RobertaSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): RobertaIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): RobertaOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (7): RobertaLayer(
#             (attention): RobertaAttention(
#               (self): RobertaSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): RobertaSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): RobertaIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): RobertaOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (8): RobertaLayer(
#             (attention): RobertaAttention(
#               (self): RobertaSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): RobertaSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): RobertaIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): RobertaOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (9): RobertaLayer(
#             (attention): RobertaAttention(
#               (self): RobertaSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): RobertaSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): RobertaIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): RobertaOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (10): RobertaLayer(
#             (attention): RobertaAttention(
#               (self): RobertaSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): RobertaSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): RobertaIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): RobertaOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (11): RobertaLayer(
#             (attention): RobertaAttention(
#               (self): RobertaSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): RobertaSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): RobertaIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): RobertaOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#       )
#     )
#     (classifier): RobertaClassificationHead(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#       (out_proj): Linear(in_features=768, out_features=1, bias=True)
#     )
#   )
# )

# %%
data_dir = '/workspace/data/reveal/'
absolute_path = '/workspace/'
reveal_dataset = Reveal(data_dir, args.gtype, to_undirected=True, seed=args.seed,
                        absolute_path=absolute_path,)
reveal_train, reveal_val, reveal_test = reveal_dataset.generate_train_test()

# %%
df = reveal_test.data

# %%
# Filter the DataFrame to get rows where 'gt' is 1
filtered_df = df[df['gt'] == 1]
text_data = []

for index, row in filtered_df.iterrows():
    file_path = row['path']
    with open(os.path.join(absolute_path, file_path), 'r') as file:
        data = file.read()
        text_data.append((index, data))

df_text_data = pd.DataFrame(text_data, columns=['id', 'processed_func'])

# %%
df_text_data
# Out:
#       id                                     processed_func
# 0      0  static int execstack2_continue ( i_ctx_t * i_c...
# 1      1  static int do_execstack ( i_ctx_t * i_ctx_p , ...
# 2      2  static gboolean logcat_dump_text ( wtap_dumper...
# 3      3  static gchar get_priority ( const guint8 * pri...
# 4      4  extern int as_mysql_step_start ( mysql_conn_t ...
# ..   ...                                                ...
# 158  158  void vp9_fdct4x4_1_c ( const int16_t * input ,...
# 159  159  static int compute_rd_thresh_factor ( int qind...
# 160  160  static void init_bit_trees ( ) {\n init_bit_tr...
# 161  161  void vp9_iwht4x4_1_add_c ( const int16_t * in ...
# 162  162  static void idct16 ( const int16_t * input , i...
#
# [163 rows x 2 columns]

# %%
from linevul.linevul_helpers import TextDataset, convert_examples_to_features

class ExtendTextDataset(TextDataset):
    def __init__(self, tokenizer, args, data_frame):
        self.examples = []
        funcs = data_frame["processed_func"].tolist()
        for i in tqdm(range(len(funcs)), desc='ExtendTextDataset'):
            self.examples.append(convert_examples_to_features(funcs[i], 1, tokenizer, args))

# %%
# multi-gpu evaluate
if args.n_gpu > 1:
    model = torch.nn.DataParallel(model)

# %%
def explain(model, tokenizer, data_frame=None): 
    """ 
        return (sample_idx, lines, n_lines)
    """
    if data_frame is not None:
        dataset = ExtendTextDataset(tokenizer, args, data_frame)
    sampler = SequentialSampler(dataset)
    data_loader = DataLoader(dataset, sampler=sampler, batch_size=1, num_workers=0)
    model.eval()
    index = 0
    progress_bar = tqdm(data_loader, total=len(data_loader))
    extract_list = []
    for mini_batch in progress_bar:
        (input_ids, labels) = mini_batch
        ids = input_ids[0].detach().tolist()
        all_tokens = tokenizer.convert_ids_to_tokens(ids)
        all_tokens = [token.replace("Ġ", "") for token in all_tokens]
        all_tokens = [token.replace("ĉ", "Ċ") for token in all_tokens]
        with torch.no_grad():
            prob, attentions = model(input_ids=input_ids, output_attentions=True)
        lines_with_score, n_lines = extract_line_attention(attentions, all_tokens)
        extract_list.append((index, lines_with_score, n_lines, prob))
    return extract_list

# %%
extract_list= explain(model, tokenizer, df_text_data)
# Out:
# ExtendTextDataset:   0%|          | 0/163 [00:00<?, ?it/s]
#   0%|          | 0/163 [00:00<?, ?it/s]

# %%
extract_list
# Out:
# [(0,
#   [(2,
#     'returndo_execstack(i_ctx_p,op->value.boolval,op-1);',
#     1287.717628479004),
#    (0, 'staticintexecstack2_continue(i_ctx_t*i_ctx_p){', 1140.957109451294),
#    (1, 'os_ptrop=osp;', 452.06596183776855),
#    (3, '}', 60.458709716796875)],
#   4,
#   tensor([[9.9995e-01, 4.8333e-05]], device='cuda:0')),
#  (0,
#   [(16,
#     'if(opidx==0||op_def_is_internal(op_index_def(opidx)))r_clear_attrs(rq,a_executable);',
#     685.7184839248657),
#    (20,
#     'constchar*tname=rq->value.pstruct?gs_struct_type_name_string(gs_object_type(imemory,rq->value.pstruct)):"NULL";',
#     675.571328163147),
#    (21,
#     'make_const_string(rq,a_readonly|avm_foreign,strlen(tname),(constbyte*)tname);',
#     495.48153591156006),
#    (10,
#     'if(r_has_type_attrs(rp,t_null,a_executable)&&!include_marks)continue;',
#     440.6631965637207),
#    (0,
#     'staticintdo_execstack(i_ctx_t*i_ctx_p,boolinclude_marks,os_ptrop1){',
#     437.7697401046753),
#    (12, 'ref_assign_old(op1,rq,rp,"execstack");', 327.3784227371216),
#    (9, 'constref*rp=ref_stack_index(&e_stack,(long)i);', 316.7333984375),
#    (15, 'uintopidx=op_index(rq);', 218.56017875671387),
#    (6, 'for(i=0,rq=arefs+asize;', 206.57111072540283),
#    (19, 'caset_struct:caset_astruct:{', 194.82201957702637),
#    (2, 'ref*arefs=op1->value.refs;', 179.08091259002686),
#    (3, 'uintasize=r_size(op1);', 175.8724889755249),
#    (13, 'switch(r_type(rq)){', 165.38775157928467),
#    (1, 'os_ptrop=osp;', 128.38586235046387),
#    (27, 'pop(op-op1);', 124.2750883102417),
#    (14, 'caset_operator:{', 106.8107557296753),
#    (7, 'rq!=arefs;', 94.19689846038818),
#    (5, 'ref*rq;', 74.06437015533447),
#    (11, '--rq;', 67.61996078491211),
#    (8, '++i){', 65.92850589752197),
#    (4, 'uinti;', 58.2928991317749),
#    (24, 'default:;', 56.28505897521973),
#    (17, 'break;', 54.507978439331055),
#    (28, 'return0;', 52.601487159729004),
#    (22, 'break;', 44.422682762145996),
#    (18, '}', 35.51980400085449),
#    (26, '}', 33.69432735443115),
#    (25, '}', 32.97705268859863),
#    (23, '}', 30.54243278503418),
#    (29, '}', 12.234416961669922)],
#   30,
#   tensor([[9.9993e-01, 6.9012e-05]], device='cuda:0')),
#  (0,
#   [(0,
#     'staticgbooleanlogcat_dump_text(wtap_dumper*wdh,conststructwtap_pkthdr*phdr,constguint8*pd,int*err){',
#     535.3867301940918),
#    (33, 'priority=get_priority((constguint8*)(pd+6*4));', 299.5681276321411),
#    (24, 'priority=get_priority((constguint8*)(pd+5*4));', 285.8003740310669),
#    (14,
#     'conststructdumper_t*dumper=(conststructdumper_t*)wdh->priv;',
#     274.5898017883301),
#    (13,
#     'constunionwtap_pseudo_header*pseudo_header=&phdr->pseudo_header;',
#     273.35939025878906),
#    (32, 'nanoseconds=(constguint32*)(pd+4*4);', 271.23712635040283),
#    (23, 'nanoseconds=(constguint32*)(pd+4*4);', 264.7786684036255),
#    (31, 'datetime=(constguint32*)(pd+3*4);', 244.19714736938477),
#    (22, 'datetime=(constguint32*)(pd+3*4);', 235.5059757232666),
#    (25, 'tag=(constgchar*)(pd+5*4+1);', 235.0703639984131),
#    (30, 'tid=(constgint*)(pd+2*4);', 219.401349067688),
#    (16, '*err=WTAP_ERR_REC_TYPE_UNSUPPORTED;', 218.34595775604248),
#    (21, 'tid=(constgint*)(pd+2*4);', 213.11783599853516),
#    (15, 'if(phdr->rec_type!=REC_TYPE_PACKET){', 208.1997833251953),
#    (28, 'elseif(pseudo_header->logcat.version==2){', 200.73990535736084),
#    (29, 'pid=(constgint*)(pd+4);', 191.94028568267822),
#    (20, 'pid=(constgint*)(pd+4);', 183.03785037994385),
#    (34, 'tag=(constchar*)(pd+6*4+', 180.75073623657227),
#    (19, 'if(pseudo_header->logcat.version==1){', 173.2664098739624),
#    (26, 'log=tag+strlen(tag)+1;', 151.46759223937988),
#    (12, 'constguint32*nanoseconds;', 126.06716728210449),
#    (11, 'constguint32*datetime;', 104.7919225692749),
#    (10, 'constgchar*str_end;', 99.7288646697998),
#    (9, 'constgchar*str_begin;', 97.02687549591064),
#    (8, 'gchar*log_part;', 89.55829048156738),
#    (6, 'constgint*tid;', 84.1178150177002),
#    (7, 'constgchar*log;', 82.22182655334473),
#    (4, 'constgchar*tag;', 81.94836902618408),
#    (5, 'constgint*pid;', 78.13645935058594),
#    (1, 'gchar*buf;', 69.5552225112915),
#    (3, 'gcharpriority;', 60.871588706970215),
#    (2, 'gintlength;', 58.689852714538574),
#    (17, 'returnFALSE;', 47.553378105163574),
#    (27, '}', 27.25987720489502),
#    (18, '}', 25.96067237854004)],
#   35,
#   tensor([[9.9993e-01, 6.5583e-05]], device='cuda:0')),
#  (0,
#   [(2,
#     "if(*priority>=(guint8)sizeof(priorities))return'?';",
#     1019.9701671600342),
#    (1, 'staticgcharpriorities[]="??VDIWEFS";', 894.9562797546387),
#    (0, 'staticgcharget_priority(constguint8*priority){', 741.082124710083),
#    (3, 'returnpriorities[(int)*priority];', 505.1521911621094),
#    (4, '}', 40.15120315551758)],
#   5,
#   tensor([[9.9995e-01, 4.9115e-05]], device='cuda:0')),
#  (0,
#   [(8,
#     'if(!step_ptr->job_ptr->db_index&&((!step_ptr->job_ptr->details||!step_ptr->job_ptr->details->submit_time)&&!step_ptr->job_ptr->resize_time)){',
#     680.2989168167114),
#    (0,
#     'externintas_mysql_step_start(mysql_conn_t*mysql_conn,structstep_record*step_ptr){',
#     381.6545944213867),
#    (20,
#     'if(check_connection(mysql_conn)!=SLURM_SUCCESS)returnESLURM_DB_CONNECTION;',
#     365.3593645095825),
#    (22,
#     'if(step_ptr->job_ptr->details)tasks=step_ptr->job_ptr->details->num_tasks;',
#     352.60443210601807),
#    (9,
#     'error("as_mysql_step_start:""Notinputingthisjob,ithasnosubmittime.");',
#     334.18211936950684),
#    (24,
#     'snprintf(node_list,BUFFER_SIZE,"%s",step_ptr->job_ptr->nodes);',
#     332.3676481246948),
#    (14,
#     'if(step_ptr->start_time>submit_time)start_time=step_ptr->start_time;',
#     323.69591331481934),
#    (29, 'elseif(step_ptr->step_id==SLURM_BATCH_SCRIPT){', 290.9995574951172),
#    (13,
#     'submit_time=start_time=step_ptr->job_ptr->resize_time;',
#     246.58248329162598),
#    (18,
#     'submit_time=step_ptr->job_ptr->details->submit_time;',
#     225.97259044647217),
#    (26, 'task_dist=step_ptr->step_layout->task_dist;', 205.45881175994873),
#    (25, 'nodes=step_ptr->step_layout->node_cnt;', 195.63948440551758),
#    (12, 'if(step_ptr->job_ptr->resize_time){', 184.27424240112305),
#    (5, 'char*node_inx=NULL,*step_name=NULL;', 175.3980598449707),
#    (1, 'inttasks=0,nodes=0,task_dist=0;', 174.95766258239746),
#    (17, 'start_time=step_ptr->start_time;', 154.1444215774536),
#    (23, 'elsetasks=step_ptr->cpu_count;', 150.81547737121582),
#    (4, 'charnode_list[BUFFER_SIZE];', 140.795654296875),
#    (2, 'intrc=SLURM_SUCCESS;', 140.47371578216553),
#    (3, 'chartemp_bit[BUF_SIZE];', 136.74716186523438),
#    (6, 'time_tstart_time,submit_time;', 130.90496730804443),
#    (27, 'node_inx=step_ptr->network;', 129.18521404266357),
#    (21, 'if(slurmdbd_conf){', 119.6118803024292),
#    (30, 'if(step_ptr->step_', 99.96525859832764),
#    (10, 'returnSLURM_ERROR;', 95.90946292877197),
#    (7, 'char*query=NULL;', 80.18608283996582),
#    (16, 'else{', 39.97193145751953),
#    (28, '}', 28.136174201965332),
#    (19, '}', 27.361976623535156),
#    (11, '}', 26.58629608154297),
#    (15, '}', 25.916939735412598)],
#   31,
#   tensor([[0.9967, 0.0033]], device='cuda:0')),
#  (0,
#   [(13,
#     'uint32_tarray_task_id=(job_ptr->array_job_id)?job_ptr->array_task_id:NO_VAL;',
#     413.795108795166),
#    (16,
#     'if((!job_ptr->details||!job_ptr->details->submit_time)&&!job_ptr->resize_time){',
#     400.7423400878906),
#    (0,
#     'externintas_mysql_job_start(mysql_conn_t*mysql_conn,structjob_record*job_ptr){',
#     381.5701570510864),
#    (20,
#     'if(check_connection(mysql_conn)!=SLURM_SUCCESS)returnESLURM_DB_CONNECTION;',
#     371.2633409500122),
#    (17,
#     'error("as_mysql_job_start:""Notinputingthisjob,ithasnosubmittime.");',
#     350.7949619293213),
#    (21, 'debug2("as_mysql_slurmdb_job_start()called");', 273.12323665618896),
#    (15,
#     'job_array_struct_t*array_recs=job_ptr->array_recs;',
#     252.19818305969238),
#    (2, 'char*nodes=NULL,*jname=NULL,*node_inx=NULL;', 231.2953462600708),
#    (9,
#     'time_tbegin_time,check_time,start_time,submit_time;',
#     222.47406005859375),
#    (14, 'uint64_tjob_db_inx=job_ptr->db_index;', 218.71485710144043),
#    (5, 'char*gres_req=NULL,*gres_alloc=NULL;', 198.70258140563965),
#    (30, 'submit_time=job_ptr->details->submit_time;', 185.25741004943848),
#    (29, 'begin_time=job_ptr->details->begin_time;', 180.03429126739502),
#    (31, 'start_time=job_ptr->start_time;', 164.2548303604126),
#    (25, 'submit_time=job_ptr->resize_time;', 160.800461769104),
#    (4, 'char*block_id=NULL,*partition=NULL;', 159.79886531829834),
#    (26, 'start_time=job_ptr->resize_time;', 159.35254669189453),
#    (24, 'begin_time=job_ptr->resize_time;', 154.52604961395264),
#    (22, 'job_state=job_ptr->job_state;', 147.84685230255127),
#    (23, 'if(job_ptr->resize_time){', 147.5905590057373),
#    (1, 'intrc=SLURM_SUCCESS;', 140.74041175842285),
#    (10, 'uint32_twckeyid=0;', 134.07551860809326),
#    (6, 'chartemp_bit[BUF_SIZE];', 132.9933729171753),
#    (33, 'if(job_ptr->state_reason==', 123.50517845153809),
#    (11, 'uint32_tjob_state;', 103.64788150787354),
#    (12, 'intnode_cnt=0;', 103.2925968170166),
#    (18, 'returnSLURM_ERROR;', 99.5309009552002),
#    (3, 'inttrack_steps=0;', 92.74453639984131),
#    (7, 'char*query=NULL;', 84.65063667297363),
#    (8, 'intreinit=0;', 84.42863941192627),
#    (28, 'else{', 44.82817459106445),
#    (27, '}', 29.159162521362305),
#    (19, '}', 28.354458808898926),
#    (32, '}', 26.776905059814453)],
#   34,
#   tensor([[0.9943, 0.0057]], device='cuda:0')),
#  (0,
#   [(27,
#     'if(row&&(node_ptr->node_state==slurm_atoul(row[0]))&&my_reason&&row[1]&&!xstrcasecmp(my_reason,row[1])){',
#     639.5050640106201),
#    (0,
#     'externintas_mysql_node_down(mysql_conn_t*mysql_conn,structnode_record*node_ptr,time_tevent_time,char*reason,uint32_treason_uid){',
#     587.9321966171265),
#    (28,
#     'debug("as_mysql_node_down:nochangeneeded%u==%s""and%s==%s",node_ptr->node_state,row[0],my_reason,row',
#     587.7554903030396),
#    (19,
#     'query=xstrdup_printf("selectstate,reasonfrom\\"%s_%s\\"where""time_end=0andnode_name=\'%s\';',
#     466.4438667297363),
#    (6,
#     'if(check_connection(mysql_conn)!=SLURM_SUCCESS)returnESLURM_DB_CONNECTION;',
#     350.74926948547363),
#    (25,
#     'elsemy_reason=slurm_add_slash_to_quotes(node_ptr->reason);',
#     316.3485908508301),
#    (24,
#     'if(reason)my_reason=slurm_add_slash_to_quotes(reason);',
#     289.316951751709),
#    (8, 'error("%s:%dnoclustername",THIS_FILE,__LINE__);', 251.14056015014648),
#    (20,
#     '",mysql_conn->cluster_name,event_table,node_ptr->name);',
#     249.79175662994385),
#    (21, 'result=mysql_db_query_ret(mysql_conn,query,0);', 228.29024982452393),
#    (16, 'error("nodeptrhasnotres_list!");', 178.74369525909424),
#    (23, 'if(!result)returnSLURM_ERROR;', 162.25690078735352),
#    (26, 'row=mysql_fetch_row(result);', 156.56407356262207),
#    (15, 'if(!node_ptr->tres_str){', 152.8015308380127),
#    (7, 'if(!mysql_conn->cluster_name){', 146.43051433563232),
#    (1, 'intrc=SLURM_SUCCESS;', 142.68810176849365),
#    (12, 'error("Nonode_ptrgiven!");', 138.71247577667236),
#    (4, 'MYSQL_RES*result=NULL;', 129.07025051116943),
#    (11, 'if(!node_ptr){', 105.84901714324951),
#    (5, 'MYSQL_ROWrow;', 100.42387580871582),
#    (17, 'returnSLURM_ERROR;', 98.9975357055664),
#    (9, 'returnSLURM_ERROR;', 97.49015617370605),
#    (13, 'returnSLURM_ERROR;', 95.45146656036377),
#    (22, 'xfree(query);', 89.64750576019287),
#    (2, 'char*query=NULL;', 83.17131805419922),
#    (3, 'char*my_reason;', 78.68552207946777),
#    (14, '}', 28.308879852294922),
#    (18, '}', 26.65443992614746),
#    (10, '}', 26.36778736114502)],
#   29,
#   tensor([[9.9991e-01, 9.3063e-05]], device='cuda:0')),
#  (0,
#   [(23,
#     'fprintf(stderr,"usage:t-dnparser[--to-str|--to-der]\\n");',
#     526.3592910766602),
#    (10, 'elseif(argc==2&&!strcmp(argv[1],"--to-der")){', 464.43218421936035),
#    (12,
#     'if(!feof(stdin))fail("readerrororinputtoolarge");',
#     419.23419284820557),
#    (13, 'err=ksba_dn_str2der(inputbuf,&buf,&len);', 406.7263116836548),
#    (5, 'if(argc==2&&!strcmp(argv[1],"--to-str")){', 386.381760597229),
#    (7, 'if(!feof(stdin))fail("readerrororinputtoolarge");', 330.4233236312866),
#    (11, 'fread(inputbuf,1,sizeofinputbuf,stdin);', 282.79173946380615),
#    (15, 'fwrite(buf,len,1,stdout);', 257.10288429260254),
#    (6, 'fread(inputbuf,1,sizeofinputbuf,stdin);', 240.25838947296143),
#    (0, 'intmain(intargc,char**argv){', 217.74496269226074),
#    (17, 'elseif(argc==1){', 202.64641189575195),
#    (14, 'fail_if_err(err);', 178.66168403625488),
#    (8, 'fail("noyetimplemented");', 165.91879177093506),
#    (4, 'gpg_error_terr;', 138.33472156524658),
#    (1, 'charinputbuf[4096];', 134.1744623184204),
#    (20, 'test_2();', 118.36912822723389),
#    (18, 'test_0();', 114.97237777709961),
#    (19, 'test_1();', 110.16783046722412),
#    (2, 'unsignedchar*buf;', 103.5247163772583),
#    (3, 'size_tlen;', 94.50421810150146),
#    (24, 'return1;', 66.0186996459961),
#    (22, 'else{', 63.686357498168945),
#    (26, 'return0;', 58.966551780700684),
#    (16, '}', 43.28403663635254),
#    (21, '}', 39.34424018859863),
#    (9, '}', 38.41650199890137),
#    (25, '}', 33.40946388244629),
#    (27, '}', 13.617063522338867)],
#   28,
#   tensor([[9.9985e-01, 1.5296e-04]], device='cuda:0')),
#  (0,
#   [(1,
#     '#defineVFF_CM_genericRGB15#defineVFF_CM_ntscRGB1#defineVFF_CM_NONE0#defineVFF_DEP_DECORDER0x4#defineVFF_DEP_NSORDER0x8#defineVFF_DES_RAW0#defineVFF_LOC_IMPLICIT1#defineVFF_MAPTYP_NONE0#defineVFF_MAPTYP_1_BYTE1#defineVFF_MAPTYP_2_BYTE2#defineVFF_MAPTYP_4_BYTE4#defineVFF_MAPTYP_FLOAT5#defineVFF_MAPTYP_DOUBLE7#defineVFF_MS_NONE0#defineVFF_MS_ONEPERBAND1#defineVFF_MS_SHARED3#defineVFF_TYP_BIT0#defineVFF_TYP_1_BYTE1#defineVFF_TYP_2_BYTE2#defineVFF_TYP_4_BYTE4#defineVFF_TYP_FLOAT5#defineVFF_TYP_DOUBLE9typedefstruct_ViffInfo{',
#     3220.226541996002),
#    (7,
#     'unsignedintlocation_type,location_dimension,number_of_images,number_data_bands,data_storage_type,data_encode_scheme,map_scheme,map_storage_type,map_rows,map_columns,map_subrows,map_enable,maps_per_cycle,color_space_model;',
#     875.0065546035767),
#    (2,
#     'unsignedcharidentifier,file_type,release,version,machine_dependency,reserve[3];',
#     267.08017349243164),
#    (0,
#     'staticImage*ReadVIFFImage(constImageInfo*image_info,ExceptionInfo*exception){',
#     257.7347717285156),
#    (6, 'floatx_bits_per_pixel,y_bits_per_pixel;', 207.42010402679443),
#    (10, 'doublemin_value,scale_factor,value;', 142.92811489105225),
#    (14, 'MagickSizeTypenumber_pixels;', 127.89933109283447),
#    (4, 'unsignedintrows,columns,subrows;', 118.47638511657715),
#    (5, 'intx_offset,y_offset;', 117.55877876281738),
#    (15, 'registerIndexPacket*indexes;', 105.19722366333008),
#    (13, 'MagickBooleanTypestatus;', 103.20564651489258),
#    (16, 'registerssize_tx;', 98.07907104492188),
#    (3, 'charcomment[512];', 82.06092643737793),
#    (17, 'registerPixelPacket*q', 78.95530986785889),
#    (11, 'Image*image;', 61.2644681930542),
#    (9, 'ViffInfo;', 59.74466037750244),
#    (12, 'intbit;', 51.70809745788574),
#    (8, '}', 28.15526008605957)],
#   18,
#   tensor([[0.9928, 0.0072]], device='cuda:0')),
#  (0,
#   [(25,
#     'if(init_io_cache(&param->read_cache,info->dfile,(uint)param->read_buffer_length,READ_CACHE,share->pack.header_length,1,MYF(MY_WME))){',
#     722.0644683837891),
#    (24,
#     'if(!param->using_global_keycache)(void)init_key_cache(dflt_key_cache,param->key_cache_block_size,param->use_buffers,0,0);',
#     607.3839979171753),
#    (22,
#     'if(info->s->options&(HA_OPTION_CHECKSUM|HA_OPTION_COMPRESS_RECORD))param->testflag|=T_CALC_CHECKSUM;',
#     563.1006631851196),
#    (13,
#     'new_header_length=(param->testflag&T_UNPACK)?0L:share->pack.header_length;',
#     351.9871244430542),
#    (0,
#     'intmi_repair(MI_CHECK*param,registerMI_INFO*info,char*name,intrep_quick){',
#     342.13994884490967),
#    (18,
#     'printf("-recovering(withkeycache)MyISAM-table\'%s\'\\n",name);',
#     331.3251781463623),
#    (19,
#     'printf("Datarecords:%s\\n",llstr(info->state->records,llbuff));',
#     311.39092445373535),
#    (23, 'DBUG_ASSERT(param->use_buffers<SIZE_T_MAX);', 263.13999366760254),
#    (10, 'bzero((char*)&sort_info,sizeof(sort_info));', 240.03092765808105),
#    (11, 'bzero((char*)&sort_param,sizeof(sort_param));', 236.62813568115234),
#    (17, 'if(!(param->testflag&T_SILENT)){', 214.57148838043213),
#    (2, 'ha_rowsstart_records,new_header_length;', 169.39423370361328),
#    (6, 'charllbuff[22],llbuff2[22];', 163.6300926208496),
#    (16, 'sort_param.sort_info=&sort_info;', 158.91268825531006),
#    (9, 'DBUG_ENTER("mi_repair");', 157.13953495025635),
#    (5, 'MYISAM_SHARE*share=info->s;', 154.26254844665527),
#    (8, 'MI_SORT_PARAMsort_param;', 137.48437213897705),
#    (12, 'start_records=info->state->records;', 136.7999496459961),
#    (21, 'param->testflag|=T_REP;', 133.21890544891357),
#    (7, 'SORT_INFOsort_info;', 102.33098030090332),
#    (1, 'interror,got_error;', 96.65533447265625),
#    (3, 'my_off_tdel;', 93.1406364440918),
#    (15, 'new_file=-1;', 89.22821235656738),
#    (14, 'got_error=1;', 86.4749059677124),
#    (4, 'Filenew_file;', 67.42651176452637),
#    (26, 'bzero(&', 47.74301528930664),
#    (20, '}', 26.92623996734619)],
#   27,
#   tensor([[9.9964e-01, 3.5795e-04]], device='cuda:0')),
#  (0,
#   [(15,
#     'if((new_file=mysql_file_create(mi_key_file_datatmp,fn_format(param->temp_filename,param->temp_filename,"",INDEX_TMP_EXT,2+4),0,param->tmpfile_createflag,MYF(0)))<=0){',
#     899.4570608139038),
#    (19,
#     'if(filecopy(param,new_file,share->kfile,0L,(ulong)share->base.keystart,"headerblock"))gotoerr;',
#     478.4692268371582),
#    (13,
#     'if(!(param->testflag&T_SILENT))printf("-SortingindexforMyISAM-table\'%s\'\\n",name);',
#     459.5381374359131),
#    (12,
#     'key++,keyinfo++)if(keyinfo->key_alg==HA_KEY_ALG_RTREE)DBUG_RETURN(0);',
#     416.2755489349365),
#    (16,
#     'mi_check_print_error(param,"Can\'tcreatenewtempfile:\'%s\'",param->temp_filename);',
#     373.3443384170532),
#    (14,
#     'fn_format(param->temp_filename,name,"",MI_NAME_IEXT,2+4+32);',
#     335.5050172805786),
#    (24,
#     'if(!mi_is_key_active(info->s->state.key_map,key))continue;',
#     330.9053030014038),
#    (0,
#     'intmi_sort_index(MI_CHECK*param,registerMI_INFO*info,char*name){',
#     302.5825319290161),
#    (4, 'my_off_tindex_pos[HA_MAX_POSSIBLE_KEY];', 238.54045486450195),
#    (21, 'for(key=0,keyinfo=&share->keyinfo[0];', 231.5971555709839),
#    (10, 'for(key=0,keyinfo=&share->keyinfo[0];', 217.35458755493164),
#    (20, 'param->new_file_pos=share->base.keystart;', 194.63572597503662),
#    (9, 'DBUG_ENTER("mi_sort_index");', 178.25164127349854),
#    (7, 'MYISAM_SHARE*share=info->s;', 151.79956340789795),
#    (25, 'if(share->state.key_root[key]', 141.95868396759033),
#    (2, 'reg1MI_KEYDEF*keyinfo;', 133.19909954071045),
#    (17, 'DBUG_RETURN(-1);', 131.4612979888916),
#    (5, 'uintr_locks,w_locks;', 116.17409229278564),
#    (23, 'key++,keyinfo++){', 111.46230888366699),
#    (22, 'key<share->base.keys;', 111.23646640777588),
#    (8, 'MI_STATE_INFOold_state;', 108.78021335601807),
#    (11, 'key<share->base.keys;', 102.4570083618164),
#    (1, 'reg2uintkey;', 73.17022609710693),
#    (6, 'intold_lock;', 70.33995628356934),
#    (3, 'Filenew_file;', 67.05430030822754),
#    (18, '}', 27.179412841796875)],
#   26,
#   tensor([[9.9988e-01, 1.1672e-04]], device='cuda:0')),
#  (0,
#   [(13,
#     'constchar*sopt="hVb:o:p:rsnP:c:dvk:e:f:tl:x:T:D:";',
#     426.4374256134033),
#    (46,
#     '"discard",required_argument,NULL,QEMU_NBD_OPT_DISCARD}',
#     330.936598777771),
#    (42,
#     '"cache",required_argument,NULL,QEMU_NBD_OPT_CACHE}',
#     300.8842887878418),
#    (44, '"aio",required_argument,NULL,QEMU_NBD_OPT_AIO}', 300.4114351272583),
#    (38, '"load-snapshot",required_argument,NULL,\'l\'}', 221.38677787780762),
#    (40, '"nocache",no_argument,NULL,\'n\'}', 203.2358570098877),
#    (28, '"read-only",no_argument,NULL,\'r\'}', 202.94168663024902),
#    (36, '"snapshot",no_argument,NULL,\'s\'}', 189.36114883422852),
#    (30, '"partition",required_argument,NULL,\'P\'}', 189.33384227752686),
#    (34, '"disconnect",no_argument,NULL,\'d\'}', 188.35038948059082),
#    (26, '"offset",required_argument,NULL,\'o\'}', 181.512131690979),
#    (32, '"connect",required_argument,NULL,\'c\'}', 178.1694507598877),
#    (24, '"socket",required_argument,NULL,\'k\'}', 175.90870666503906),
#    (0, 'intmain(intargc,char**argv){', 172.1779899597168),
#    (22, '"port",required_argument,NULL,\'p\'}', 172.0109634399414),
#    (16, '"help",no_argument,NULL,\'h\'}', 171.68730545043945),
#    (20, '"bind",required_argument,NULL,\'b\'}', 170.8671531677246),
#    (18, '"version",no_argument,NULL,\'V\'}', 164.3289041519165),
#    (12, 'constchar*sn_id_or_name=NULL;', 156.72457695007324),
#    (11, 'QemuOpts*sn_opts=NULL;', 156.54752445220947),
#    (4, 'uint16_tnbdflags=0;', 129.86283493041992),
#    (3, 'off_tdev_offset=0;', 116.91314029693604),
#    (6, 'constchar*bindto=NULL;', 108.75198459625244),
#    (14, 'structoptionlopt[]={', 99.44438934326172),
#    (10, 'off_tfd_size;', 96.24697208404541),
#    (8, 'char*sockpath=NULL;', 95.87652969360352),
#    (1, 'BlockBackend*blk;', 92.74985027313232),
#    (7, 'constchar*port=NULL;', 92.26098823547363),
#    (2, 'BlockDriverState*bs;', 87.25617933273315),
#    (9, 'char*device=NULL;', 83.9192476272583),
#    (5, 'booldisconnect=false;', 73.05776596069336),
#    (48, '"detect-', 55.9719295501709),
#    (35, ',{', 39.64407730102539),
#    (29, ',{', 39.35517501831055),
#    (47, ',{', 37.90841197967529),
#    (41, ',{', 37.63006401062012),
#    (23, ',{', 37.56388759613037),
#    (33, ',{', 37.46709632873535),
#    (37, ',{', 37.20675086975098),
#    (45, ',{', 37.15557670593262),
#    (27, ',{', 36.93084716796875),
#    (43, ',{', 36.77207088470459),
#    (19, ',{', 36.495049476623535),
#    (17, ',{', 36.147573471069336),
#    (21, ',{', 35.91090393066406),
#    (39, ',{', 35.53001022338867),
#    (25, ',{', 35.38485622406006),
#    (31, ',{', 33.93551731109619),
#    (15, '{', 25.242841720581055)],
#   49,
#   tensor([[0.9985, 0.0015]], device='cuda:0')),
#  (0,
#   [(6,
#     'if((script=fopen_priv(*analyze_script_file_name,"w"))==NULL)pg_fatal("Couldnotopenfile\\"%s\\":%s\\n",*analyze_script_file_name,getErrorText());',
#     692.8288402557373),
#    (15,
#     'fprintf(script,"echo%sanytables,youmightwanttoremovethemandrestorethemafter%s\\n",ECHO_QUOTE,ECHO_QUOTE);',
#     530.8191299438477),
#    (14,
#     'fprintf(script,"echo%sIfyouhaveusedALTERTABLEtomodifythestatisticstargetfor%s\\n",ECHO_QUOTE,ECHO_QUOTE);',
#     525.5808954238892),
#    (10,
#     'fprintf(script,"echo%ssoyoursystemisusable,andthengatherstatisticstwicemore%s\\n",ECHO_QUOTE,ECHO_QUOTE);',
#     499.4597978591919),
#    (11,
#     'fprintf(script,"echo%swithincreasingaccuracy.Whenitisdone,yoursystemwill%s\\n",ECHO_QUOTE,ECHO_QUOTE);',
#     495.8251123428345),
#    (9,
#     '#endiffprintf(script,"echo%sThisscriptwillgenerateminimaloptimizerstatisticsrapidly%s\\n",ECHO_QUOTE,ECHO_QUOTE);',
#     489.0918664932251),
#    (12,
#     'fprintf(script,"echo%shavethedefaultlevelofoptimizerstatistics.%s\\n",ECHO_QUOTE,ECHO_QUOTE);',
#     455.49467372894287),
#    (5,
#     '*analyze_script_file_name=psprintf("%sanalyze_new_cluster.%s",SCRIPT_PREFIX,SCRIPT_EXT);',
#     448.2205219268799),
#    (4,
#     'if(os_info.user_specified)user_specification=psprintf("-U\\"%s\\"",os_info.user);',
#     378.1162166595459),
#    (0,
#     'voidcreate_script_for_cluster_analyze(char**analyze_script_file_name){',
#     299.33295154571533),
#    (13, 'fprintf(script,"echo%s\\n\\n",ECHO_BLANK);', 273.1251792907715),
#    (7, '#ifndefWIN32fprintf(script,"#!/bin/sh\\n\\n");', 271.0320920944214),
#    (8, '#elsefprintf(script,"@echooff\\n");', 186.29724884033203),
#    (3,
#     'prep_status("Creatingscripttoanalyzenewcluster");',
#     174.17850303649902),
#    (2, 'char*user_specification="";', 112.69215297698975),
#    (16, 'fprintf(script,"echo', 89.01023387908936),
#    (1, 'FILE*script=NULL;', 88.35307693481445)],
#   17,
#   tensor([[9.9991e-01, 8.7548e-05]], device='cuda:0')),
#  (0,
#   [(0,
#     'staticvoidvacuum_all_databases(vacuumingOptions*vacopts,boolanalyze_in_stages,constchar*maintenance_db,constchar*host,constchar*port,constchar*username,enumtrivalueprompt_password,intconcurrentCons,constchar*progname,boolecho,boolquiet){',
#     971.8963460922241),
#    (28,
#     'vacuum_one_database(dbname,vacopts,ANALYZE_NO_STAGE,NULL,host,port,username,prompt_password,concurrentCons,progname,echo,quiet);',
#     662.4076442718506),
#    (18,
#     'vacuum_one_database(dbname,vacopts,stage,NULL,host,port,username,prompt_password,concurrentCons,progname,echo,quiet);',
#     578.3921737670898),
#    (6,
#     'result=executeQuery(conn,"SELECTdatnameFROMpg_databaseWHEREdatallowconnORDERBY1;',
#     347.0418128967285),
#    (5,
#     'conn=connectMaintenanceDatabase(maintenance_db,host,port,username,prompt_password,progname);',
#     331.82108974456787),
#    (17, 'dbname=PQgetvalue(result,i,0);', 233.06027793884277),
#    (27, 'dbname=PQgetvalue(result,i,0);', 211.98017978668213),
#    (11, 'stage<ANALYZE_NUM_STAGES;', 190.76586246490479),
#    (14, 'i<PQntuples(result);', 171.34162044525146),
#    (24, 'i<PQntuples(result);', 162.88571071624756),
#    (9, 'if(analyze_in_stages){', 156.83702945709229),
#    (8, 'PQfinish(conn);', 128.42629146575928),
#    (7, '",progname,echo);', 126.63363075256348),
#    (10, 'for(stage=0;', 106.05608367919922),
#    (16, 'constchar*dbname;', 103.7562084197998),
#    (13, 'for(i=0;', 102.33954238891602),
#    (31, 'PQclear(result);', 101.4250602722168),
#    (23, 'for(i=0;', 98.92900943756104),
#    (26, 'constchar*dbname;', 92.90108585357666),
#    (1, 'PGconn*conn;', 78.73454093933105),
#    (15, 'i++){', 77.22902297973633),
#    (12, 'stage++){', 76.42812442779541),
#    (2, 'PGresult*result;', 74.8193187713623),
#    (25, 'i++){', 69.99434185028076),
#    (3, 'intstage;', 53.52047920227051),
#    (4, 'inti;', 51.03778553009033),
#    (22, 'else{', 48.60041809082031),
#    (20, '}', 32.772624015808105),
#    (19, '}', 31.873302459716797),
#    (29, '}', 30.489973068237305),
#    (30, '}', 30.336742401123047),
#    (21, '}', 28.92209815979004),
#    (32, '}', 11.207463264465332)],
#   33,
#   tensor([[9.9994e-01, 5.5143e-05]], device='cuda:0')),
#  (0,
#   [(17,
#     'if(server_version>=90600)res=executeQuery(conn,"SELECTdatname,""coalesce(rolname,(selectrolnamefrompg_authidwhereoid=(selectdatdbafrompg_databasewheredatname=\'template0\'))),""pg_encoding_to_char(d.encoding),""datcollate',
#     1043.0306024551392),
#    (9,
#     'elseif(server_version>=70100)res=executeQuery(conn,"SELECTpg_encoding_to_char(encoding),""null::textASdatcollate,null::textASdatctype""FROMpg_database""WHEREdatname=\'template0\'");',
#     786.1356058120728),
#    (10,
#     'elseres=executeQuery(conn,"SELECTpg_encoding_to_char(encoding),""null::textASdatcollate,null::textASdatctype""FROMpg_database""WHEREdatname=\'template1\'");',
#     704.052360534668),
#    (8,
#     'if(server_version>=80400)res=executeQuery(conn,"SELECTpg_encoding_to_char(encoding),""datcollate,datctype""FROMpg_database""WHEREdatname=\'template0\'");',
#     683.4262208938599),
#    (14,
#     'if(!PQgetisnull(res,0,2))default_ctype=pg_strdup(PQgetvalue(res,0,2));',
#     487.12907695770264),
#    (12,
#     'if(!PQgetisnull(res,0,0))default_encoding=pg_strdup(PQgetvalue(res,0,0));',
#     476.6090383529663),
#    (13,
#     'if(!PQgetisnull(res,0,1))default_collate=pg_strdup(PQgetvalue(res,0,1));',
#     474.62174892425537),
#    (7,
#     'fprintf(OPF,"--\\n--Databasecreation\\n--\\n\\n");',
#     259.60638427734375),
#    (11, 'if(PQntuples(res)>0){', 174.7329454421997),
#    (1, 'PQExpBufferbuf=createPQExpBuffer();', 167.61618328094482),
#    (0, 'staticvoiddumpCreateDB(PGconn*conn){', 152.6370506286621),
#    (2, 'char*default_encoding=NULL;', 119.51552391052246),
#    (4, 'char*default_ctype=NULL;', 117.451340675354),
#    (3, 'char*default_collate=NULL;', 115.59764289855957),
#    (16, 'PQclear(res);', 96.963059425354),
#    (5, 'PGresult*res;', 69.05081367492676),
#    (6, 'inti;', 45.09312438964844),
#    (15, '}', 26.596293449401855)],
#   18,
#   tensor([[9.9993e-01, 6.6153e-05]], device='cuda:0')),
#  (0,
#   [(3,
#     '#endif#ifdefined(OPENSSL_CPUID_OBJ)&&(defined(__arm__)||defined(__arm)||defined(__aarch64__))#include"arm_arch.h"#if__ARM_MAX_ARCH__>=7#ifdefined(BSAES_ASM)#defineBSAES_CAPABLE(OPENSSL_armcap_P&ARMV7_NEON)#endif#ifdefined(VPAES_ASM)#defineVPAES_CAPABLE(OPENSSL_armcap_P&ARMV7_NEON)#endif#defineHWAES_CAPABLE(OPENSSL_armcap_P&ARMV8_AES)#defineHWAES_set_encrypt_keyaes_v8_set_encrypt_key#defineHWAES_set_decrypt_keyaes_v8_set_decrypt_key#defineHWAES_encryptaes_v8_encrypt#defineHWAES_decryptaes_v8_decrypt#defineHWAES_cbc_encryptaes_v8_cbc_encrypt#defineHWAES_ctr32_encrypt_blocksaes_v8_ctr32_encrypt_blocks#endif#endif#ifdefined(HWAES_CAPABLE)intHWAES_set_encrypt_key(constunsignedchar*userKey,constintbits,AES_KEY*key);',
#     3854.352840423584),
#    (7,
#     'voidHWAES_cbc_encrypt(constunsignedchar*in,unsignedchar*out,size_tlength,constAES_KEY*key,unsignedchar*ivec,constintenc);',
#     567.4263586997986),
#    (4,
#     'intHWAES_set_decrypt_key(constunsignedchar*userKey,constintbits,AES_KEY*key);',
#     369.7659683227539),
#    (6,
#     'voidHWAES_decrypt(constunsignedchar*in,unsignedchar*out,constAES_KEY*key);',
#     347.63606548309326),
#    (5,
#     'voidHWAES_encrypt(constunsignedchar*in,unsignedchar*out,constAES_KEY*key);',
#     343.3198652267456),
#    (0,
#     'constEVP_CIPHER*EVP_aes_##keylen##_##mode(void)\\{',
#     307.08000087738037),
#    (1, 'return&aes_##keylen##_##mode;', 158.87284469604492),
#    (8, 'voidH', 25.570231437683105),
#    (2, '}', 24.261887550354004)],
#   9,
#   tensor([[9.9977e-01, 2.3183e-04]], device='cuda:0')),
#  (0,
#   [(0,
#     'voidtraverse_commit_list(structrev_info*revs,show_commit_fnshow_commit,show_object_fnshow_object,void*data){',
#     510.2314205169678),
#    (31,
#     'die("unknownpendingobject%s(%s)",oid_to_hex(&obj->oid),name);',
#     411.59306812286377),
#    (24,
#     'process_tree(revs,(structtree*)obj,show_object,NULL,&base,path,data);',
#     385.2699956893921),
#    (28,
#     'process_blob(revs,(structblob*)obj,show_object,NULL,path,data);',
#     344.8283500671387),
#    (16, 'if(obj->flags&(UNINTERESTING|SEEN))continue;', 298.6596794128418),
#    (6,
#     'if(commit->tree)add_pending_tree(revs,commit->tree);',
#     266.18929290771484),
#    (12,
#     'structobject_array_entry*pending=revs->pending.objects+i;',
#     260.76786518096924),
#    (5, 'while((commit=get_revision(revs))!=NULL){', 242.82535457611084),
#    (23, 'if(obj->type==OBJ_TREE){', 205.3534688949585),
#    (19, 'show_object(obj,NULL,name,data);', 194.46358489990234),
#    (27, 'if(obj->type==OBJ_BLOB){', 191.9760570526123),
#    (17, 'if(obj->type==OBJ_TAG){', 189.45810317993164),
#    (33, 'object_array_clear(&revs->pending);', 181.27619171142578),
#    (4, 'strbuf_init(&base,PATH_MAX);', 176.26439762115479),
#    (10, 'i<revs->pending.nr;', 141.8580846786499),
#    (14, 'constchar*name=pending->name;', 140.44565677642822),
#    (18, 'obj->flags|=SEEN;', 140.159818649292),
#    (22, 'if(!path)path="";', 139.9107608795166),
#    (13, 'structobject*obj=pending->item;', 138.24267768859863),
#    (15, 'constchar*path=pending->path;', 136.28254508972168),
#    (34, 'strbuf_release(&base);', 135.1881227493286),
#    (7, 'show_commit(commit,data);', 128.4508581161499),
#    (9, 'for(i=0;', 91.59497928619385),
#    (2, 'structcommit*commit;', 82.98844337463379),
#    (3, 'structstrbufbase;', 79.50557041168213),
#    (11, 'i++){', 71.62550830841064),
#    (1, 'inti;', 51.90199375152588),
#    (20, 'continue;', 49.2543249130249),
#    (25, 'continue;', 48.310601234436035),
#    (29, 'continue;', 48.00468063354492),
#    (21, '}', 33.17019271850586),
#    (26, '}', 32.502540588378906),
#    (32, '}', 31.698293685913086),
#    (8, '}', 31.67568874359131),
#    (30, '}', 29.455371856689453),
#    (35, '}', 12.186220169067383)],
#   36,
#   tensor([[9.9987e-01, 1.2907e-04]], device='cuda:0')),
#  (0,
#   [(0,
#     'staticvoidshow_object(structobject*object,conststructname_path*path,constchar*last,void*data){',
#     828.5888442993164),
#    (9, 'bitmap_set(base,bitmap_pos);', 531.5819778442383),
#    (3, 'bitmap_pos=bitmap_position(object->oid.hash);', 501.0167579650879),
#    (6, 'bitmap_pos=ext_index_add_object(object,name);', 500.69182205200195),
#    (5, 'char*name=path_name(path,last);', 363.30413722991943),
#    (1, 'structbitmap*base=data;', 317.41836738586426),
#    (4, 'if(bitmap_pos<0){', 283.97421646118164),
#    (7, 'free(name);', 212.63022994995117),
#    (2, 'intbitmap_pos;', 210.81164932250977),
#    (8, '}', 93.8300895690918),
#    (10, '}', 34.52056121826172)],
#   11,
#   tensor([[9.9993e-01, 7.0133e-05]], device='cuda:0')),
#  (0,
#   [(13,
#     'if(bo->fetch_objcore->stobj->stevedore!=NULL)ObjFreeObj(bo->wrk,bo->fetch_objcore);',
#     411.94029998779297),
#    (15,
#     'http_PutResponse(bo->beresp,"HTTP/1.1",503,"Backendfetchfailed");',
#     353.8963985443115),
#    (19,
#     'if(!VTAILQ_EMPTY(&bo->fetch_objcore->objhead->waitinglist)){',
#     329.0127000808716),
#    (14,
#     'HTTP_Setup(bo->beresp,bo->ws,bo->vsl,SLT_BerespMethod);',
#     328.14549255371094),
#    (0,
#     'staticenumfetch_stepvbf_stp_error(structworker*wrk,structbusyobj*bo){',
#     316.4287061691284),
#    (31,
#     'VCL_backend_error_method(bo->vcl,wrk,NULL,bo,synth_body)',
#     311.272310256958),
#    (7,
#     'CHECK_OBJ_NOTNULL(bo->fetch_objcore,OBJCORE_MAGIC);',
#     283.027868270874),
#    (6, 'CHECK_OBJ_NOTNULL(bo,BUSYOBJ_MAGIC);', 242.51152992248535),
#    (17, 'http_SetHeader(bo->beresp,"Server:Varnish");', 236.18751621246338),
#    (5, 'CHECK_OBJ_NOTNULL(wrk,WORKER_MAGIC);', 233.98582935333252),
#    (8, 'AN(bo->fetch_objcore->flags&OC_F_BUSY);', 225.4579038619995),
#    (16, 'http_TimeHeader(bo->beresp,"Date:",now);', 223.66471004486084),
#    (12, 'VSLb_ts_busyobj(bo,"Error",now);', 216.52121829986572),
#    (9, 'assert(bo->director_state==DIR_S_NULL);', 189.88577556610107),
#    (29, 'synth_body=VSB_new_auto();', 166.5153512954712),
#    (18, 'bo->fetch_objcore->t_origin=now;', 160.73816013336182),
#    (20, 'bo->fetch_objcore->ttl=1;', 159.65958786010742),
#    (11, 'now=W_TIM_real(wrk);', 159.058837890625),
#    (25, 'bo->fetch_objcore->ttl=0;', 155.6015748977661),
#    (26, 'bo->fetch_objcore->grace=0;', 153.39729595184326),
#    (22, 'bo->fetch_objcore->keep=5;', 151.12091636657715),
#    (21, 'bo->fetch_objcore->grace=5;', 149.803560256958),
#    (27, 'bo->fetch_objcore->keep=0;', 147.82074165344238),
#    (10, 'wrk->stats->fetch_failed++;', 127.6519889831543),
#    (1, 'ssize_tl,ll,o;', 122.21684646606445),
#    (4, 'structvsb*synth_body;', 105.9578332901001),
#    (30, 'AN(synth_body);', 102.59991359710693),
#    (3, 'uint8_t*ptr;', 93.40272045135498),
#    (2, 'doublenow;', 47.924386978149414),
#    (24, 'else{', 40.37144756317139),
#    (28, '}', 29.420106887817383),
#    (23, '}', 26.642961502075195)],
#   32,
#   tensor([[9.9990e-01, 9.6470e-05]], device='cuda:0')),
#  (0,
#   [(0,
#     'voiddissect_q931_cause_ie(tvbuff_t*tvb,intoffset,intlen,proto_tree*tree,inthf_cause_value,guint8*cause_value,constvalue_string*ie_vals){',
#     1410.618800163269),
#    (3,
#     'dissect_q931_cause_ie_unsafe(tvb,offset,len,tree,hf_cause_value,cause_value,ie_vals);',
#     1112.0050106048584),
#    (4, 'have_valid_q931_pi=have_valid_q931_pi_save;', 781.5925445556641),
#    (1,
#     'gbooleanhave_valid_q931_pi_save=have_valid_q931_pi;',
#     546.2852039337158),
#    (2, 'have_valid_q931_pi=FALSE;', 294.17175579071045),
#    (5, '}', 28.349170684814453)],
#   6,
#   tensor([[9.9994e-01, 6.1409e-05]], device='cuda:0')),
#  (0,
#   [(0,
#     'staticintparse_CRestrictionArray(tvbuff_t*tvb,intoffset,proto_tree*parent_tree,proto_tree*pad_tree,constchar*fmt,...){',
#     584.063458442688),
#    (15,
#     'proto_tree_add_uint(tree,hf_mswsp_crestrictarray_present,tvb,offset,1,present);',
#     514.1155014038086),
#    (12,
#     'proto_tree_add_uint(tree,hf_mswsp_crestrictarray_count,tvb,offset,1,count);',
#     493.62807273864746),
#    (9,
#     'tree=proto_tree_add_subtree(parent_tree,tvb,offset,0,ett_CRestrictionArray,&item,txt);',
#     490.49983310699463),
#    (24,
#     'offset=parse_CRestriction(tvb,offset,tree,pad_tree,&r,"Restriction[%d]",i);',
#     464.64253330230713),
#    (19,
#     'offset=parse_padding(tvb,offset,4,pad_tree,"paddingCRestrictionPresent");',
#     383.503999710083),
#    (7,
#     'txt=wmem_strdup_vprintf(wmem_packet_scope(),fmt,ap);',
#     361.8546619415283),
#    (14, 'present=tvb_get_guint8(tvb,offset);', 280.21584701538086),
#    (11, 'count=tvb_get_guint8(tvb,offset);', 256.45714950561523),
#    (27, 'proto_item_set_end(item,tvb,offset);', 212.34520816802979),
#    (6, 'va_start(ap,fmt);', 131.55319690704346),
#    (1, 'guint8present,count;', 107.27328968048096),
#    (8, 'va_end(ap);', 105.93357849121094),
#    (10, 'pad_tree=tree;', 104.7649974822998),
#    (20, 'for(i=0;', 100.39291477203369),
#    (23, 'structCRestrictionr;', 98.9344835281372),
#    (2, 'proto_tree*tree;', 90.63673400878906),
#    (17, 'if(present){', 90.4874267578125),
#    (3, 'proto_item*item;', 88.1210584640503),
#    (13, 'offset+=1;', 86.0029935836792),
#    (4, 'constchar*txt;', 83.5986442565918),
#    (5, 'va_listap;', 81.22638034820557),
#    (16, 'offset+=1;', 80.52171993255615),
#    (22, 'i++){', 72.35393238067627),
#    (21, 'i<count;', 65.50436782836914),
#    (28, 'returnoffset;', 59.190420150756836),
#    (18, 'unsignedi;', 58.48611927032471),
#    (25, '}', 33.999284744262695),
#    (26, '}', 31.312211990356445),
#    (29, '}', 11.590960502624512)],
#   30,
#   tensor([[9.9994e-01, 6.2610e-05]], device='cuda:0')),
#  (0,
#   [(14,
#     'proto_tree_add_item(tree,hf_mswsp_categorizationspec_cmaxres,tvb,offset,4,ENC_LITTLE_ENDIAN);',
#     649.3129072189331),
#    (0,
#     'intparse_CCategorizationSpec(tvbuff_t*tvb,intoffset,proto_tree*parent_tree,proto_tree*pad_tree,constchar*fmt,...){',
#     612.015528678894),
#    (13,
#     'offset=parse_CInGroupSortAggregSets(tvb,offset,tree,pad_tree,"InGroupSortAggregSets");',
#     561.85133934021),
#    (8,
#     'tree=proto_tree_add_subtree(parent_tree,tvb,offset,0,ett_CCategorizationSpec,&item,txt);',
#     538.823691368103),
#    (12,
#     'offset=parse_CSortAggregSet(tvb,offset,tree,pad_tree,"SortAggregSet");',
#     496.5490140914917),
#    (11,
#     'offset=parse_CAggregSet(tvb,offset,tree,pad_tree,"AggregSet");',
#     467.2660322189331),
#    (10,
#     'offset=parse_CCategSpec(tvb,offset,tree,pad_tree,"Spec");',
#     389.41304302215576),
#    (6,
#     'txt=wmem_strdup_vprintf(wmem_packet_scope(),fmt,ap);',
#     375.79588890075684),
#    (9,
#     'offset=parse_CColumnSet(tvb,offset,tree,"csColumns");',
#     368.0541286468506),
#    (16, 'proto_item_set_end(item,tvb,offset);', 240.95183277130127),
#    (5, 'va_start(ap,fmt);', 136.29179859161377),
#    (7, 'va_end(ap);', 115.60800743103027),
#    (2, 'proto_tree*tree;', 97.2660493850708),
#    (3, 'constchar*txt;', 94.79105377197266),
#    (1, 'proto_item*item;', 93.8030138015747),
#    (4, 'va_listap;', 82.25730800628662),
#    (15, 'offset+=4;', 80.27176666259766),
#    (17, 'returnoffset;', 58.18744659423828),
#    (18, '}', 12.857542037963867)],
#   19,
#   tensor([[9.9990e-01, 1.0432e-04]], device='cuda:0')),
#  (0,
#   [(0,
#     'staticintparse_CTableColumn(tvbuff_t*tvb,intoffset,proto_tree*parent_tree,proto_tree*pad_tree,structCTableColumn*col,constchar*fmt,...){',
#     569.0250778198242),
#    (43,
#     'tree=proto_tree_add_subtree(parent_tree,tvb,offset,0,ett_CTableColumn,&item,txt);',
#     432.72834968566895),
#    (41,
#     'txt=wmem_strdup_vprintf(wmem_packet_scope(),fmt,ap);',
#     343.24615573883057),
#    (44,
#     'offset=parse_CFullPropSpec(tvb,offset,tree,pad_tree,&v,',
#     278.5772771835327),
#    (23, '0xA,"DBAGGTTYPE_REPRESENTATIVEOF"}', 258.7599630355835),
#    (15, '0x6,"DBAGGTTYPE_CHILDCOUNT"}', 214.6167507171631),
#    (25, '0xB,"DBAGGTTYPE_EDITDISTANCE"}', 213.19272232055664),
#    (17, '0x7,"DBAGGTTYPE_BYFREQ"}', 207.85026168823242),
#    (21, '0x9,"DBAGGTTYPE_DATERANGE"}', 204.41052627563477),
#    (3, '0x0,"DBAGGTTYPE_BYNONE"}', 200.67455863952637),
#    (19, '0x8,"DBAGGTTYPE_FIRST"}', 188.33009719848633),
#    (11, '0x4,"DBAGGTTYPE_AVG"}', 183.157639503479),
#    (13, '0x5,"DBAGGTTYPE_COUNT"}', 182.3610029220581),
#    (5, '0x1,"DBAGGTTYPE_SUM"}', 182.2599744796753),
#    (35, 'enumvTypevtype_valhi=VT_EMPTY;', 179.19175148010254),
#    (1, 'staticconstvalue_stringDBAGGTTYPE[]={', 175.1338176727295),
#    (7, '0x2,"DBAGGTTYPE_MAX"}', 174.02240467071533),
#    (9, '0x3,"DBAGGTTYPE_MIN"}', 171.22481727600098),
#    (34, 'enumvTypevtype_val=VT_EMPTY;', 163.41025638580322),
#    (40, 'va_start(ap,fmt);', 128.40060424804688),
#    (33, 'structvtype_data*type;', 103.40954494476318),
#    (39, 'constchar*modifier="";', 99.99813079833984),
#    (42, 'va_end(ap);', 99.962082862854),
#    (36, 'structCFullPropSpecv;', 93.0148515701294),
#    (37, 'constchar*txt;', 86.52312183380127),
#    (31, 'proto_tree*tree;', 81.59934329986572),
#    (32, 'va_listap;', 79.44644737243652),
#    (30, 'proto_item*item;', 77.99392127990723),
#    (38, 'guint8used;', 77.30752372741699),
#    (27, '0,NULL}', 63.07140350341797),
#    (26, ',{', 37.24644470214844),
#    (20, ',{', 36.48526382446289),
#    (24, ',{', 35.38202381134033),
#    (4, ',{', 34.964927673339844),
#    (14, ',{', 34.90811061859131),
#    (18, ',{', 34.521239280700684),
#    (8, ',{', 34.35834980010986),
#    (12, ',{', 34.28810691833496),
#    (22, ',{', 33.628968238830566),
#    (10, ',{', 33.41384983062744),
#    (16, ',{', 32.91902303695679),
#    (6, ',{', 32.86081504821777),
#    (29, ';', 25.657928466796875),
#    (28, '}', 25.334227561950684),
#    (2, '{', 23.817607879638672)],
#   45,
#   tensor([[9.9964e-01, 3.5700e-04]], device='cuda:0')),
#  (0,
#   [(16,
#     'if(!(mask&KADM5_PRINCIPAL)||(mask&KADM5_MOD_NAME)||(mask&KADM5_MOD_TIME)||(mask&KADM5_LAST_PWD_CHANGE)||(mask&KADM5_MKVNO)||(mask&KADM5_AUX_ATTRIBUTES)||(mask&KADM5_LAST_SUCCESS)||(mask&KADM5_LAST_FAILED)||(mask&KADM5_FAIL_AUTH_COUNT))returnKADM5_BAD_MASK;',
#     1900.2755317687988),
#    (0,
#     'kadm5_ret_tkadm5_create_principal_3(void*server_handle,kadm5_principal_ent_tentry,longmask,intn_ks_tuple,krb5_key_salt_tuple*ks_tuple,char*password){',
#     877.7158250808716),
#    (17,
#     'if((mask&KADM5_KEY_DATA)&&entry->n_key_data!=0)returnKADM5_BAD_MASK;',
#     467.4795265197754),
#    (15,
#     'check_1_6_dummy(entry,mask,n_ks_tuple,ks_tuple,&password);',
#     354.05355739593506),
#    (12, 'krb5_key_salt_tuple*new_ks_tuple=NULL;', 251.14027214050293),
#    (18, 'if((mask&KADM5_POLICY)&&(mask&K', 245.26578330993652),
#    (8, 'kadm5_server_handle_thandle=server_handle;', 193.93148136138916),
#    (14, 'krb5_clear_error_message(handle->context);', 186.9653091430664),
#    (6, 'krb5_tl_data*tl_data_tail;', 171.13237190246582),
#    (4, 'krb5_booleanhave_polent=FALSE;', 161.85283756256104),
#    (13, 'CHECK_HANDLE(server_handle);', 159.50407695770264),
#    (3, 'kadm5_policy_ent_recpolent;', 155.60775566101074),
#    (10, 'krb5_kvnoact_kvno;', 153.95947933197021),
#    (9, 'krb5_keyblock*act_mkey;', 145.93397045135498),
#    (11, 'intnew_n_ks_tuple=0;', 145.17450046539307),
#    (2, 'osa_princ_ent_recadb;', 145.05360507965088),
#    (1, 'krb5_db_entry*kdb;', 138.21195030212402),
#    (5, 'krb5_int32now;', 102.24998760223389),
#    (7, 'unsignedintret;', 57.55424499511719)],
#   19,
#   tensor([[9.9988e-01, 1.1799e-04]], device='cuda:0')),
#  (0,
#   [(18,
#     'haystack_u8=mbfl_convert_encoding(haystack,&_haystack_u8,mbfl_no_encoding_utf8);',
#     499.2805881500244),
#    (29,
#     'needle_u8=mbfl_convert_encoding(needle,&_needle_u8,mbfl_no_encoding_utf8);',
#     457.7839479446411),
#    (0,
#     'intmbfl_strpos(mbfl_string*haystack,mbfl_string*needle,intoffset,intreverse){',
#     373.63521671295166),
#    (5,
#     'if(haystack==NULL||haystack->val==NULL||needle==NULL||needle->val==NULL){',
#     309.25432300567627),
#    (10, 'u8_enc=mbfl_no2encoding(mbfl_no_encoding_utf8);', 307.51536655426025),
#    (16,
#     'if(haystack->no_encoding!=mbfl_no_encoding_utf8){',
#     280.6023864746094),
#    (11, 'if(u8_enc==NULL||u8_enc->mblen_table==NULL){', 273.5590991973877),
#    (27, 'if(needle->no_encoding!=mbfl_no_encoding_utf8){', 269.04356384277344),
#    (3, 'constmbfl_string*haystack_u8,*needle_u8=NULL;', 245.0604419708252),
#    (2, 'mbfl_string_haystack_u8,_needle_u8;', 229.38506889343262),
#    (17, 'mbfl_string_init(&_haystack_u8);', 213.01764965057373),
#    (28, 'mbfl_string_init(&_needle_u8);', 210.8268222808838),
#    (43, 'if(haystack_u8->len<needle_u8->len', 200.13453769683838),
#    (14, 'u8_tbl=u8_enc->mblen_table;', 193.7916202545166),
#    (38, 'if(needle_u8->len<1){', 153.248366355896),
#    (9, 'constmbfl_encoding*u8_enc;', 152.7199239730835),
#    (19, 'if(haystack_u8==NULL){', 149.7849407196045),
#    (30, 'if(needle_u8==NULL){', 143.08169269561768),
#    (25, 'haystack_u8=haystack;', 123.40349769592285),
#    (4, 'constunsignedchar*u8_tbl;', 122.09773826599121),
#    (36, 'needle_u8=needle;', 104.119553565979),
#    (42, 'result=-1;', 74.60278797149658),
#    (31, 'result=-4;', 72.56136989593506),
#    (39, 'result=-8;', 72.08250045776367),
#    (20, 'result=-4;', 68.68473529815674),
#    (12, 'return-8;', 56.82387065887451),
#    (40, 'gotoout;', 55.293511390686035),
#    (6, 'return-8;', 54.42851448059082),
#    (32, 'gotoout;', 53.02875804901123),
#    (21, 'gotoout;', 51.216468811035156),
#    (1, 'intresult;', 47.13279724121094),
#    (35, 'else{', 43.26920127868652),
#    (24, 'else{', 41.1777982711792),
#    (41, '}', 27.89568328857422),
#    (34, '}', 27.278361320495605),
#    (33, '}', 27.089208602905273),
#    (37, '}', 26.981170654296875),
#    (26, '}', 26.754493713378906),
#    (22, '}', 26.533011436462402),
#    (7, '}', 26.43795680999756),
#    (23, '}', 26.427087783813477),
#    (13, '}', 26.4038143157959),
#    (15, '}', 25.693729400634766),
#    (8, '{', 24.023841857910156)],
#   44,
#   tensor([[9.9912e-01, 8.7538e-04]], device='cuda:0')),
#  (0,
#   [(0,
#     'mbfl_string*mbfl_buffer_converter_feed_result(mbfl_buffer_converter*convd,mbfl_string*string,mbfl_string*result){',
#     995.2386980056763),
#    (12,
#     'returnmbfl_memory_device_result(&convd->device,result);',
#     576.8826379776001),
#    (11, 'result->no_encoding=convd->to->no_encoding;', 502.94495964050293),
#    (9, 'mbfl_convert_filter_flush(convd->filter2);', 479.56983184814453),
#    (6, 'mbfl_convert_filter_flush(convd->filter1);', 405.85672760009766),
#    (1, 'if(convd==NULL||string==NULL||result==NULL){', 373.504677772522),
#    (4, 'mbfl_buffer_converter_feed(convd,string);', 336.4179449081421),
#    (8, 'if(convd->filter2!=NULL){', 305.75819396972656),
#    (5, 'if(convd->filter1!=NULL){', 231.71628189086914),
#    (2, 'returnNULL;', 88.04111099243164),
#    (10, '}', 63.744136810302734),
#    (7, '}', 62.59182548522949),
#    (3, '}', 39.23000526428223),
#    (13, '}', 21.780715942382812)],
#   14,
#   tensor([[9.9995e-01, 4.9195e-05]], device='cuda:0')),
#  (0,
#   [(0,
#     'intjbig2_decode_halftone_region(Jbig2Ctx*ctx,Jbig2Segment*segment,Jbig2HalftoneRegionParams*params,constbyte*data,constsize_tsize,Jbig2Image*image,Jbig2ArithCx*GB_stats){',
#     852.8129644393921),
#    (22,
#     'GI=jbig2_decode_gray_scale_image(ctx,segment,data,size,params->HMMR,params->HGW,params->HGH,HBPP,params->HENABLESKIP,HSKIP,params->HTEMPLATE,GB_stats);',
#     807.5769052505493),
#    (24,
#     'jbig2_error(ctx,JBIG2_SEVERITY_WARNING,segment->number,"unabletoacquiregray-scaleimage,skippinghalftoneimage");',
#     526.2040243148804),
#    (16,
#     'jbig2_error(ctx,JBIG2_SEVERITY_WARNING,segment->number,"nopatterndictionaryfound,skippinghalftoneimage");',
#     466.55362606048584),
#    (12,
#     'jbig2_error(ctx,JBIG2_SEVERITY_WARNING,segment->number,"unhandledoptionHENABLESKIP");',
#     430.7670555114746),
#    (14,
#     'HPATS=jbig2_decode_ht_region_get_hpats(ctx,segment);',
#     298.1005115509033),
#    (10,
#     'memset(image->data,params->HDEFPIXEL,image->stride*image->height);',
#     271.7118730545044),
#    (21, 'while(HNUMPATS>(1<<++HBPP));', 204.21024894714355),
#    (11, 'if(params->HENABLESKIP==1){', 176.02356433868408),
#    (19, 'HNUMPATS=HPATS->n_patterns;', 163.24370002746582),
#    (4, 'Jbig2Image*HSKIP=NULL;', 138.71692657470703),
#    (5, 'Jbig2PatternDict*HPATS;', 131.22162532806396),
#    (2, 'uint32_tHNUMPATS;', 118.47565746307373),
#    (7, 'uint32_tmg,ng;', 101.49938678741455),
#    (3, 'uint8_t**GI;', 101.42144441604614),
#    (15, 'if(!HPATS){', 101.39639377593994),
#    (1, 'uint32_tHBPP;', 101.16311550140381),
#    (9, 'uint8_tgray_val;', 100.43890380859375),
#    (28, 'mg<params->HGH;', 99.90357494354248),
#    (8, 'int32_tx,y;', 95.23801231384277),
#    (30, 'for(ng=0;', 91.67395877838135),
#    (23, 'if(!GI){', 91.48157405853271),
#    (27, 'for(mg=0;', 90.42614269256592),
#    (20, 'HBPP=0;', 81.09136581420898),
#    (29, '++mg){', 65.89802837371826),
# ...
#    (12,
#     'x->mv_row_max=(cm->mb_rows-1)*8+BORDER_MV_PIXELS_B16;',
#     422.76513671875),
#    (5, 'intmb_y_offset=0,arf_y_offset=0,gld_y_offset=0;', 329.0408706665039),
#    (11, 'x->mv_row_min=-BORDER_MV_PIXELS_B16;', 278.07430839538574),
#    (15, 'xd->plane[0].pre[0].stride=buf->y_stride;', 270.7159996032715),
#    (19, 'mi_local.mbmi.ref_frame[0]=LAST_FRAME;', 260.4604911804199),
#    (16, 'xd->plane[1].dst.stride=buf->uv_stride;', 248.44425201416016),
#    (18, 'mi_local.mbmi.sb_type=BLOCK_16X16;', 242.13370609283447),
#    (14, 'xd->plane[0].dst.stride=buf->y_stride;', 238.69933986663818),
#    (26, 'intarf_y_in_offset=arf_y_offset;', 232.83131217956543),
#    (20, 'mi_local.mbmi.ref_frame[1]=NONE;', 229.32038688659668),
#    (24, 'MVgld_left_mv=gld_top_mv;', 218.1125888824463),
#    (25, 'intmb_y_in_offset=mb_y_offset;', 216.7960615158081),
#    (2, 'MACROBLOCKD*constxd=&x->e_mbd;', 206.69358730316162),
#    (3, 'VP9_COMMON*constcm=&cpi->common;', 193.7839756011963),
#    (1, 'MACROBLOCK*constx=&cpi->mb;', 186.73083114624023),
#    (4, 'intmb_col,mb_row,offset=0;', 176.37098026275635),
#    (17, 'xd->mi[0]=&mi_local;', 164.75974655151367),
#    (22, 'mb_row<cm->mb_rows;', 161.30565929412842),
#    (10, 'vp9_zero(mi_local);', 133.68839931488037),
#    (6, 'MVgld_top_mv={', 127.27782917022705),
#    (21, 'for(mb_row=0;', 121.62287998199463),
#    (13, 'xd->up_available=0;', 119.97852230072021),
#    (9, 'MODE_INFOmi_local;', 106.11908435821533),
#    (23, 'mb_row++){', 99.3897123336792),
#    (27, 'intgld_y', 61.45070457458496),
#    (7, '0,0}', 59.258389472961426),
#    (8, ';', 25.427550315856934)],
#   28,
#   tensor([[9.9990e-01, 9.6960e-05]], device='cuda:0')),
#  (0,
#   [(14,
#     'xd->lossless=cm->base_qindex==0&&cm->y_dc_delta_q==0&&cm->uv_dc_delta_q==0&&cm->uv_ac_delta_q==0;',
#     699.7819347381592),
#    (17,
#     'x->itxm_add=xd->lossless?vp9_iwht4x4_add:vp9_idct4x4_add;',
#     474.1406030654907),
#    (16,
#     'x->fwd_txm4x4=xd->lossless?vp9_fwht4x4:vp9_fdct4x4;',
#     453.96575450897217),
#    (25, 'vp9_initialize_me_consts(cpi,cm->base_qindex);', 296.04423332214355),
#    (13, 'vp9_zero(rd_opt->tx_select_threshes);', 236.78513717651367),
#    (0, 'staticvoidencode_frame_internal(VP9_COMP*cpi){', 231.4320068359375),
#    (1, 'SPEED_FEATURES*constsf=&cpi->sf;', 217.4262809753418),
#    (12, 'vp9_zero(rd_opt->tx_select_diff);', 212.58223342895508),
#    (10, 'vp9_zero(rd_opt->comp_pred_diff);', 211.1235876083374),
#    (2, 'RD_OPT*constrd_opt=&cpi->rd;', 209.5014419555664),
#    (24, 'vp9_initialize_rd_consts(cpi);', 206.3809471130371),
#    (5, 'MACROBLOCKD*constxd=&x->e_mbd;', 204.95401287078857),
#    (15, 'cm->tx_mode=select_tx_mode(cpi);', 203.18487167358398),
#    (4, 'VP9_COMMON*constcm=&cpi->common;', 198.1335678100586),
#    (23, 'vp9_frame_init_quantizer(cpi);', 194.13616752624512),
#    (9, 'vp9_zero(cpi->coef_counts);', 189.96626949310303),
#    (11, 'vp9_zero(rd_opt->filter_diff);', 188.49114418029785),
#    (3, 'MACROBLOCK*constx=&cpi->mb;', 185.5577621459961),
#    (26, 'init_encode_frame_mb_context(cpi);', 185.42394256591797),
#    (21, 'cpi->zbin_mode_boost_enabled=0;', 182.44715404510498),
#    (6, 'xd->mi=cm->mi_grid_visible;', 157.96756839752197),
#    (7, 'xd->mi[0]=cm->mi;', 145.94573307037354),
#    (20, 'cm->lf.filter_level=0;', 138.94010066986084),
#    (8, 'vp9_zero(cm->counts);', 138.38029861450195),
#    (18, 'if(xd->lossless){', 120.20035934448242),
#    (19, 'x->optimize=0;', 91.62095832824707),
#    (22, '}', 31.309505462646484)],
#   27,
#   tensor([[9.9993e-01, 6.5914e-05]], device='cuda:0')),
#  (0,
#   [(0,
#     'staticvoidupdate_state(VP9_COMP*cpi,PICK_MODE_CONTEXT*ctx,intmi_row,intmi_col,BLOCK_SIZEbsize,intoutput_enabled){',
#     587.6404161453247),
#    (24,
#     'vp9_cyclic_refresh_update_segment(cpi,&xd->mi[0]->mbmi,mi_row,mi_col,bsize,1',
#     520.5552797317505),
#    (21,
#     'mi_addr->mbmi.segment_id=vp9_get_segment_id(cm,map,bsize,mi_row,mi_col);',
#     476.4884252548218),
#    (20,
#     'constuint8_t*constmap=seg->update_map?cpi->segmentation_map:cm->last_frame_seg_map;',
#     427.56130027770996),
#    (23, 'if(cpi->oxcf.aq_mode==CYCLIC_REFRESH_AQ){', 317.83379077911377),
#    (13,
#     'constintmi_width=num_8x8_blocks_wide_lookup[bsize];',
#     288.2570161819458),
#    (14,
#     'constintmi_height=num_8x8_blocks_high_lookup[bsize];',
#     284.89902782440186),
#    (9, 'MB_MODE_INFO*constmbmi=&xd->mi[0]->mbmi;', 276.33151626586914),
#    (19, 'if(cpi->oxcf.aq_mode==COMPLEXITY_AQ){', 254.88883209228516),
#    (5, 'MACROBLOCKD*constxd=&x->e_mbd;', 212.91048336029053),
#    (3, 'RD_OPT*constrd_opt=&cpi->rd;', 207.83593654632568),
#    (10, 'MODE_INFO*mi_addr=xd->mi[0];', 204.8597640991211),
#    (16, 'assert(mi->mbmi.sb_type==bsize);', 204.84673976898193),
#    (7, 'structmacroblockd_plane*constpd=xd->plane;', 197.06484031677246),
#    (2, 'VP9_COMMON*constcm=&cpi->common;', 195.2961721420288),
#    (11, 'conststructsegmentation*constseg=&cm->seg;', 185.83835315704346),
#    (4, 'MACROBLOCK*constx=&cpi->mb;', 176.23434352874756),
#    (6, 'structmacroblock_plane*constp=x->plane;', 168.0561065673828),
#    (18, 'if(seg->enabled&&output_enabled){', 164.84881687164307),
#    (8, 'MODE_INFO*mi=&ctx->mic;', 162.9335355758667),
#    (12, 'constintmis=cm->mi_stride;', 147.50490283966064),
#    (1, 'inti,x_idx,y;', 120.8987226486206),
#    (17, '*mi_addr=*mi;', 108.23336124420166),
#    (15, 'intmax_plane;', 75.31870937347412),
#    (22, '}', 29.822688102722168)],
#   25,
#   tensor([[9.9993e-01, 6.5055e-05]], device='cuda:0')),
#  (0,
#   [(0,
#     'staticvoidset_partition_range(VP9_COMMON*cm,MACROBLOCKD*xd,intmi_row,intmi_col,BLOCK_SIZEbsize,BLOCK_SIZE*min_bs,BLOCK_SIZE*max_bs){',
#     738.0991868972778),
#    (5,
#     'MODE_INFO**prev_mi=&cm->prev_mi_grid_visible[mi_row*cm->mi_stride+mi_col];',
#     426.1885099411011),
#    (1, 'intmi_width=num_8x8_blocks_wide_lookup[bsize];', 265.1184883117676),
#    (2, 'intmi_height=num_8x8_blocks_high_lookup[bsize];', 253.5405158996582),
#    (16, 'mi=prev_mi[idy*cm->mi_stride+idx];', 252.03865814208984),
#    (27, 'mi=xd->mi[idy*cm->mi_stride-1];', 244.2167615890503),
#    (28, 'bs=mi?mi->mbmi.sb_type:bsize;', 236.70077896118164),
#    (37, 'mi=xd->mi[idx-cm->mi_stride];', 231.75578689575195),
#    (17, 'bs=mi?mi->mbmi.sb_type:bsize;', 226.47620487213135),
#    (38, 'bs=mi?mi->mbmi.sb_type:bsize', 216.20749378204346),
#    (6, 'BLOCK_SIZEbs,min_size,max_size;', 182.05642700195312),
#    (29, 'min_size=MIN(min_size,bs);', 180.78909015655518),
#    (18, 'min_size=MIN(min_size,bs);', 177.70693111419678),
#    (30, 'max_size=MAX(max_size,bs);', 176.87390995025635),
#    (19, 'max_size=MAX(max_size,bs);', 174.7503433227539),
#    (7, 'min_size=BLOCK_64X64;', 138.53375053405762),
#    (33, 'if(xd->up_available){', 134.2684030532837),
#    (8, 'max_size=BLOCK_4X4;', 134.118390083313),
#    (23, 'if(xd->left_available){', 128.09651279449463),
#    (34, 'for(idx=0;', 103.80145072937012),
#    (24, 'for(idy=0;', 96.2463788986206),
#    (13, 'for(idx=0;', 96.2221155166626),
#    (14, 'idx<mi_width;', 96.05767822265625),
#    (25, 'idy<mi_height;', 95.02995300292969),
#    (35, 'idx<mi_width;', 94.98072624206543),
#    (9, 'if(prev_mi){', 94.6012372970581),
#    (10, 'for(idy=0;', 93.53109741210938),
#    (11, 'idy<mi_height;', 91.82145595550537),
#    (4, 'MODE_INFO*mi;', 90.22594261169434),
#    (3, 'intidx,idy;', 89.39902400970459),
#    (36, '++idx){', 78.12462997436523),
#    (26, '++idy){', 75.08323097229004),
#    (15, '++idx){', 74.2398910522461),
#    (12, '++idy){', 71.11050128936768),
#    (31, '}', 29.863611221313477),
#    (22, '}', 28.75431251525879),
#    (32, '}', 27.96123695373535),
#    (21, '}', 27.83553123474121),
#    (20, '}', 27.37704086303711)],
#   39,
#   tensor([[9.9994e-01, 6.4628e-05]], device='cuda:0')),
#  (0,
#   [(19, 't3=-x2*cospi_8_64+x3*cospi_24_64;', 322.4364700317383),
#    (18, 't2=x2*cospi_24_64+x3*cospi_8_64;', 311.60826587677),
#    (1, 'ints0,s1,s2,s3,s4,s5,s6,s7;', 294.24848079681396),
#    (0,
#     'staticvoidfdct8(constint16_t*input,int16_t*output){',
#     285.2105083465576),
#    (25, 't1=(s6+s5)*cospi_16_64;', 244.13559436798096),
#    (17, 't1=(x0-x1)*cospi_16_64;', 239.56762218475342),
#    (16, 't0=(x0+x1)*cospi_16_64;', 238.33647632598877),
#    (24, 't0=(s6-s5)*cospi_16_64;', 237.50563049316406),
#    (23, 'output[6]=fdct_round_shift(t3);', 220.57716941833496),
#    (22, 'output[4]=fdct_round_shift(t1);', 215.14122772216797),
#    (20, 'output[0]=fdct_round_shift(t0);', 212.74301528930664),
#    (21, 'output[2]=fdct_round_shift(t2);', 211.61300945281982),
#    (26, 't2=fdct_round_shift(t0);', 197.95755577087402),
#    (27, 't3=fdct_round_shift(t1);', 197.1743450164795),
#    (4, 's0=input[0]+input[7];', 162.28344821929932),
#    (8, 's4=input[3]-input[4];', 161.42552375793457),
#    (7, 's3=input[3]+input[4];', 161.38815021514893),
#    (11, 's7=input[0]-input[7];', 160.83094787597656),
#    (6, 's2=input[2]+input[5];', 160.05443859100342),
#    (2, 'intt0,t1,t2,t3;', 157.65698432922363),
#    (9, 's5=input[2]-input[5];', 157.1488161087036),
#    (3, 'intx0,x1,x2,x3;', 156.07024478912354),
#    (10, 's6=input[1]-input[6];', 154.42906093597412),
#    (5, 's1=input[1]+input[6];', 153.87064170837402),
#    (31, 'x3=s7+t3;', 128.48669910430908),
#    (30, 'x2=s7-t3;', 126.79299736022949),
#    (29, 'x1=s4-t2;', 123.34035778045654),
#    (28, 'x0=s4+t2;', 121.63901710510254),
#    (13, 'x1=s1+s2;', 117.98710441589355),
#    (15, 'x3=s0-s3;', 114.85481071472168),
#    (14, 'x2=s1-s2;', 114.7479419708252),
#    (12, 'x0=s0+s3;', 114.04532146453857),
#    (32, 't0=', 35.86431694030762)],
#   33,
#   tensor([[9.9991e-01, 8.8308e-05]], device='cuda:0')),
#  (0,
#   [(0,
#     'voidvp9_fdct8x8_c(constint16_t*input,int16_t*final_output,intstride){',
#     412.44066047668457),
#    (27, 't3=-x2*cospi_8_64+x3*cospi_24_64;', 330.4453248977661),
#    (26, 't2=x2*cospi_24_64+x3*cospi_8_64;', 314.52722454071045),
#    (5, 'ints0,s1,s2,s3,s4,s5,s6,s7;', 282.6956272125244),
#    (17, 's5=(input[2*stride]-input[5*stride])*4;', 261.4750738143921),
#    (18, 's6=(input[1*stride]-input[6*stride])*4;', 260.79576206207275),
#    (19, 's7=(input[0*stride]-input[7*stride])*4;', 258.50942039489746),
#    (16, 's4=(input[3*stride]-input[4*stride])*4;', 256.83416748046875),
#    (15, 's3=(input[3*stride]+input[4*stride])*4;', 255.0076093673706),
#    (30, 'output[4*8]=fdct_round_shift(t1);', 252.5206422805786),
#    (14, 's2=(input[2*stride]+input[5*stride])*4;', 250.5999927520752),
#    (12, 's0=(input[0*stride]+input[7*stride])*4;', 249.57127380371094),
#    (13, 's1=(input[1*stride]+input[6*stride])*4;', 248.00068378448486),
#    (28, 'output[0*8]=fdct_round_shift(t0);', 240.46424102783203),
#    (29, 'output[2*8]=fdct_round_shift(t2);', 240.4405574798584),
#    (25, 't1=(x0-x1)*cospi_16_64;', 240.34405040740967),
#    (24, 't0=(x0+x1)*cospi_16_64;', 238.82962894439697),
#    (7, 'intx0,x1,x2,x3;', 152.51647758483887),
#    (6, 'intt0,t1,t2,t3;', 148.15300369262695),
#    (21, 'x1=s1+s2;', 123.09189224243164),
#    (4, 'int16_t*output=intermediate;', 120.4055814743042),
#    (20, 'x0=s0+s3;', 118.23818492889404),
#    (23, 'x3=s0-s3;', 118.09768676757812),
#    (2, 'int16_tintermediate[64];', 116.53391742706299),
#    (22, 'x2=s1-s2;', 115.81448936462402),
#    (9, 'for(i=0;', 82.13443088531494),
#    (1, 'inti,j;', 71.50516891479492),
#    (11, 'i++){', 60.891727447509766),
#    (10, 'i<8;', 58.62428379058838),
#    (8, 'inti;', 49.17651081085205),
#    (31, 'output[6', 35.56857204437256),
#    (3, '{', 26.12642002105713)],
#   32,
#   tensor([[9.9944e-01, 5.5811e-04]], device='cuda:0')),
#  (0,
#   [(0,
#     'voidvp9_fdct4x4_1_c(constint16_t*input,int16_t*output,intstride){',
#     1156.334529876709),
#    (7, '++c)sum+=input[r*stride+c];', 485.26472663879395),
#    (8, 'output[0]=sum<<1;', 347.7946968078613),
#    (5, '++r)for(c=0;', 312.0535545349121),
#    (2, 'int16_tsum=0;', 289.0129222869873),
#    (9, 'output[1]=0;', 266.8156204223633),
#    (3, 'for(r=0;', 221.75009727478027),
#    (1, 'intr,c;', 219.4411220550537),
#    (4, 'r<4;', 166.3621997833252),
#    (6, 'c<4;', 126.16672706604004),
#    (10, '}', 49.25629806518555)],
#   11,
#   tensor([[9.9992e-01, 8.1507e-05]], device='cuda:0')),
#  (0,
#   [(1,
#     'constintq=(int)(pow(vp9_dc_quant(qindex,0)/4.0,RD_THRESH_POW)*5.12);',
#     2035.3132820129395),
#    (0, 'staticintcompute_rd_thresh_factor(intqindex){', 792.1375141143799),
#    (2, 'returnMAX(q,8);', 367.5184726715088),
#    (3, '}', 33.58710479736328)],
#   4,
#   tensor([[9.9995e-01, 4.8417e-05]], device='cuda:0')),
#  (0,
#   [(2, 'init_bit_tree(cat2,2);', 559.1811408996582),
#    (3, 'init_bit_tree(cat3,3);', 503.4267997741699),
#    (6, 'init_bit_tree(cat6,14);', 498.61910247802734),
#    (4, 'init_bit_tree(cat4,4);', 489.7916069030762),
#    (0, 'staticvoidinit_bit_trees(){', 478.92964363098145),
#    (1, 'init_bit_tree(cat1,1);', 467.9818458557129),
#    (5, 'init_bit_tree(cat5,5);', 441.37245178222656),
#    (7, '}', 38.62831497192383)],
#   8,
#   tensor([[9.9993e-01, 6.5061e-05]], device='cuda:0')),
#  (0,
#   [(0,
#     'voidvp9_iwht4x4_1_add_c(constint16_t*in,uint8_t*dest,intdest_stride){',
#     628.1427783966064),
#    (18,
#     'dest[dest_stride*1]=clip_pixel(dest[dest_stride*1]+e1);',
#     538.0229148864746),
#    (17,
#     'dest[dest_stride*0]=clip_pixel(dest[dest_stride*0]+a1);',
#     518.7375373840332),
#    (19,
#     'dest[dest_stride*2]=clip_pixel(dest[dest_stride*2]+e1);',
#     507.9616994857788),
#    (20,
#     'dest[dest_stride*3]=clip_pixel(dest[dest_stride*3]+e1);',
#     462.5384645462036),
#    (10, 'op[1]=op[2]=op[3]=e1;', 298.43785762786865),
#    (6, 'a1=ip[0]>>UNIT_QUANT_SHIFT;', 265.5628309249878),
#    (16, 'a1=ip[0]-e1;', 205.79666900634766),
#    (15, 'e1=ip[0]>>1;', 193.34152126312256),
#    (4, 'constint16_t*ip=in;', 151.4298553466797),
#    (3, 'int16_ttmp[4];', 145.8753204345703),
#    (9, 'op[0]=a1;', 144.8443956375122),
#    (5, 'int16_t*op=tmp;', 138.14426612854004),
#    (7, 'e1=a1>>1;', 135.3551197052002),
#    (12, 'for(i=0;', 118.57577419281006),
#    (8, 'a1-=e1;', 116.25088310241699),
#    (2, 'inta1,e1;', 114.51597309112549),
#    (11, 'ip=tmp;', 99.33911800384521),
#    (13, 'i<4;', 87.04761600494385),
#    (14, 'i++){', 85.99131107330322),
#    (21, 'ip++;', 70.31441402435303),
#    (22, 'dest++;', 65.47900581359863),
#    (1, 'inti;', 61.019354820251465),
#    (23, '}', 33.07842826843262),
#    (24, '}', 14.070749282836914)],
#   25,
#   tensor([[9.9983e-01, 1.7245e-04]], device='cuda:0')),
#  (0,
#   [(28, 'temp2=step1[8]*cospi_2_64+step1[15]*cospi_30_64;', 385.6080150604248),
#    (27,
#     'temp1=step1[8]*cospi_30_64-step1[15]*cospi_2_64;',
#     383.46175384521484),
#    (31, 'temp1=step1[9]*cospi_14_64-step1[14]*cospi_18_64', 366.2763624191284),
#    (0,
#     'staticvoididct16(constint16_t*input,int16_t*output){',
#     262.049786567688),
#    (29, 'step2[8]=dct_const_round_shift(temp1);', 248.3984203338623),
#    (30, 'step2[15]=dct_const_round_shift(temp2);', 241.96261310577393),
#    (1, 'int16_tstep1[16],step2[16];', 198.41557216644287),
#    (18, 'step1[15]=input[30/2];', 170.87753009796143),
#    (16, 'step1[13]=input[22/2];', 167.31877517700195),
#    (14, 'step1[11]=input[26/2];', 164.3919916152954),
#    (17, 'step1[14]=input[14/2];', 164.0765323638916),
#    (12, 'step1[9]=input[18/2];', 163.1124792098999),
#    (8, 'step1[5]=input[20/2];', 162.92906284332275),
#    (9, 'step1[6]=input[12/2];', 162.07683563232422),
#    (15, 'step1[12]=input[6/2];', 160.95243453979492),
#    (5, 'step1[2]=input[8/2];', 160.8590431213379),
#    (13, 'step1[10]=input[10/2];', 160.68027305603027),
#    (10, 'step1[7]=input[28/2];', 159.0478744506836),
#    (4, 'step1[1]=input[16/2];', 158.83934020996094),
#    (25, 'step2[6]=step1[6];', 158.31340885162354),
#    (3, 'step1[0]=input[0/2];', 157.2718801498413),
#    (7, 'step1[4]=input[4/2];', 156.91931915283203),
#    (23, 'step2[4]=step1[4];', 156.37777519226074),
#    (11, 'step1[8]=input[2/2];', 155.51779651641846),
#    (21, 'step2[2]=step1[2];', 155.09311866760254),
#    (24, 'step2[5]=step1[5];', 154.69222831726074),
#    (26, 'step2[7]=step1[7];', 153.8662405014038),
#    (6, 'step1[3]=input[24/2];', 153.62422847747803),
#    (19, 'step2[0]=step1[0];', 150.612548828125),
#    (22, 'step2[3]=step1[3];', 150.2577085494995),
#    (20, 'step2[1]=step1[1];', 150.0332555770874),
#    (2, 'inttemp1,temp2;', 90.83765029907227)],
#   32,
#   tensor([[9.9993e-01, 7.4915e-05]], device='cuda:0'))]

# %%
new_text_data = []
for i in extract_list:  # (index, lines_with_score, n_lines, prob)
    nlines = i[2]
    top_10 = max(int(nlines * 0.1), 2 )  # if func less than 3 lines, select top 2
    _t = ' \n '.join(item[1] for item in i[1][:top_10])
    new_text_data.append((i[0], _t))
df_new_text_data = pd.DataFrame(new_text_data, columns=['id', 'processed_func'])

# %%
df_new_text_data
# Out:
#      id                                     processed_func
# 0     0  returndo_execstack(i_ctx_p,op->value.boolval,o...
# 1     0  if(opidx==0||op_def_is_internal(op_index_def(o...
# 2     0  staticgbooleanlogcat_dump_text(wtap_dumper*wdh...
# 3     0  if(*priority>=(guint8)sizeof(priorities))retur...
# 4     0  if(!step_ptr->job_ptr->db_index&&((!step_ptr->...
# ..   ..                                                ...
# 158   0  voidvp9_fdct4x4_1_c(constint16_t*input,int16_t...
# 159   0  constintq=(int)(pow(vp9_dc_quant(qindex,0)/4.0...
# 160   0   init_bit_tree(cat2,2); \n init_bit_tree(cat3,3);
# 161   0  voidvp9_iwht4x4_1_add_c(constint16_t*in,uint8_...
# 162   0  temp2=step1[8]*cospi_2_64+step1[15]*cospi_30_6...
#
# [163 rows x 2 columns]

# %%
new_extract_list= explain(model, tokenizer, df_new_text_data)
# Out:
# ExtendTextDataset:   0%|          | 0/163 [00:00<?, ?it/s]
#   0%|          | 0/163 [00:00<?, ?it/s]

# %%
new_extract_list[0]
# Out:
# (0,
#  [(0,
#    'returndo_execstack(i_ctx_p,op->value.boolval,op-1);',
#    1587.131251335144),
#   (1, 'staticintexecstack2_continue(i_ctx_t*i_ctx_p){', 1313.7463874816895)],
#  2,
#  tensor([[9.9993e-01, 7.1108e-05]], device='cuda:0'))

# %%
extract_list[0]
# Out:
# (0,
#  [(2,
#    'returndo_execstack(i_ctx_p,op->value.boolval,op-1);',
#    1287.717628479004),
#   (0, 'staticintexecstack2_continue(i_ctx_t*i_ctx_p){', 1140.957109451294),
#   (1, 'os_ptrop=osp;', 452.06596183776855),
#   (3, '}', 60.458709716796875)],
#  4,
#  tensor([[9.9995e-01, 4.8333e-05]], device='cuda:0'))

# %%
original_pred = [i[3].cpu().numpy()[0][1] for i in extract_list]
explain_pred = [i[3].cpu().numpy()[0][1] for i in new_extract_list]

# %%
_fidelity = []
for i in zip(original_pred, explain_pred):
    _fidelity.append(abs(i[0] - i[1]))

# %%
from statistics import mean, stdev

mean(_fidelity)
# Out:
# 0.03446935

# %%
stdev(_fidelity)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /workspace/LineVul.ipynb Cell 28 line <cell line: 1>()
# ----> <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f47415375626772617068227d@ssh-remote%2Btramchim/workspace/LineVul.ipynb#X42sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> stdev(_fidelity)
#
# File /opt/micromamba/envs/GASubgraph/lib/python3.9/statistics.py:797, in stdev(data, xbar)
#     788 def stdev(data, xbar=None):
#     789     """Return the square root of the sample variance.
#     790
#     791     See ``variance`` for arguments and other details.
#    (...)
#     795
#     796     """
# --> 797     var = variance(data, xbar)
#     798     try:
#     799         return var.sqrt()
#
# File /opt/micromamba/envs/GASubgraph/lib/python3.9/statistics.py:740, in variance(data, xbar)
#     738 if n < 2:
#     739     raise StatisticsError('variance requires at least two data points')
# --> 740 T, ss = _ss(data, xbar)
#     741 return _convert(ss / (n - 1), T)
#
# File /opt/micromamba/envs/GASubgraph/lib/python3.9/statistics.py:691, in _ss(data, c)
#     688 # The following sum should mathematically equal zero, but due to rounding
#     689 # error may not.
#     690 U, total2, count2 = _sum((x - c) for x in data)
# --> 691 assert T == U and count == count2
#     692 total -= total2 ** 2 / len(data)
#     693 assert not total < 0, 'negative sum of square deviations: %f' % total
#
# AssertionError:

# %%
len(_fidelity)
# Out:
# 163

# %%
_r = pd.DataFrame(_fidelity, columns=['fidelity'])

# %%
_r.describe()
# Out:
#          fidelity
# count  163.000000
# mean     0.034469
# std      0.174842
# min      0.000001
# 25%      0.000012
# 50%      0.000077
# 75%      0.000453
# max      0.995099
